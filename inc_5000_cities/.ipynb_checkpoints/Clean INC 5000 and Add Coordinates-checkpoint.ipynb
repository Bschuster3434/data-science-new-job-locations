# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import re
import json
import requests
import time
import pickle
import random

# %%
def get_json_response(city_state):
    #Google Maps Sample API Link for JSON
    #"https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=API_KEY"
    Base_URL = "https://maps.googleapis.com/maps/api/geocode/json?address="
    API_Key = "&key=AIzaSyCFOt6arDLmVymOYy2TrkLrRqJRIl7zk6Q"
    google_maps_url = Base_URL + city_state + API_Key
    r = requests.get(google_maps_url)
    time.sleep(.1)
    json_file = r.json()
    coor = {}
    try:
        first_result = json_file['results'][0]   
    except IndexError:
        print "Error on Result: " + city_state
    try:   
        coor['lat'] = first_result['geometry']['location']['lat']
    except IndexError:
        print "Error on Lat: " + city_state
    try:
        coor['lon'] = first_result['geometry']['location']['lng']
    except IndexError:
        print "Error on Lon: " + city_state
    return coor

# %%
f = 'Inc_5000_raw_results.csv'

# %%
df = DataFrame.from_csv(f, index_col=None)

# %%
df = df[np.isfinite(df['rank'])]

# %%
df['city_state'] = df['city'] + ', ' + df['state']
df['coded_city_state'] = [re.sub(' ', '+', place) for place in df['city_state']]

# %%
city_state_coded = df['coded_city_state'].unique()

# %%
###TEST SCRIPT FOR API###
test = city_state_coded[1]
coordinates = get_json_response(test)
test, coordinates
# Out:
# ('North+Wales,+PA', {'lat': 40.2109404, 'lon': -75.2782317})

# %%
###ONE TIME COORDINATES GRAB. NOW IN city_state_coors.pickle###
#lat_lon_dict = {}
#for city_state in city_state_coded:
#    lat_lon_dict[city_state] = get_json_response(city_state)

# %%
#with open('city_state_coors.pickle', 'wb') as handle:
#  pickle.dump(lat_lon_dict, handle)

# %%
with open('city_state_coors.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
city_state_coors = b

# %%
test_case = df.ix[1]
city_state_coors[test_case['coded_city_state']]['lat']
# Out:
# 29.7857853

# %%
city_lat = []
city_lon = []
for ccs in df['coded_city_state']:
    next_lat = city_state_coors[ccs]['lat']
    next_lon = city_state_coors[ccs]['lon']
    city_lat.append(next_lat)
    city_lon.append(next_lon)

# %%
df['city_lat'] = city_lat
df['city_lon'] = city_lon
df.index = range(len(df))

# %%
##Test Script, comparing results to Google API Results
##Testing for result mismatches
random_num = random.randint(1, len(city_state_coded))
test = city_state_coded[random_num]
coordinates = get_json_response(test)
print df[df['coded_city_state'] == test][['coded_city_state','city_lat', 'city_lon']]
print test, coordinates
# Out:
#      coded_city_state   city_lat   city_lon
# 3561      Hewlett,+NY  40.643159 -73.695686
# Hewlett,+NY {'lat': 40.6431591, 'lon': -73.6956864}

# %%
##Haversine's Formula
##Thanks to Michael Dunn
##http://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points

from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 

    # 3963.2 miles is the radius of the Earth
    miles = 3963.1676 * c
    return miles

# %%
###Next section will be the function that counts
###how many cities are within r miles of a city of interest
###I am interested in getting as much data as possible, so 
###I'm considering doing every city in the list, over 1,000,000 calcs!

start_time = time.time()


num_businesses_in_r_range = {}
for city_code in city_state_coors.iterkeys():
    test_city = city_code
    base_coors = city_state_coors[test_city]
    distances = []
    for i in range(len(df)):
        next_city_lat = df['city_lat'].ix[i]
        next_city_lon = df['city_lon'].ix[i]
        distance_in_miles = haversine(base_coors['lon'], base_coors['lat'], next_city_lon, next_city_lat)
        distances.append(distance_in_miles)
    cities_in_range = 0
    r = 30 #miles
    for i in distances:
        if i <= r:
            cities_in_range += 1
    num_businesses_in_r_range[test_city] = cities_in_range
    

end_time = time.time()

# %%
num_businesses_in_r_range
# Out:
# {'Acton,+MA': 167,
#  'Addison,+IL': 243,
#  'Addison,+TX': 140,
#  'Adrian,+MI': 9,
#  'Agoura+Hills,+CA': 90,
#  'Aiea,+HI': 6,
#  'Akron,+OH': 32,
#  'Alameda,+CA': 201,
#  'Albany,+NY': 16,
#  'Albuquerque,+NM': 4,
#  'Alcoa,+TN': 14,
#  'Aledo,+TX': 13,
#  'Alexandria,+VA': 336,
#  'Algona,+WA': 106,
#  'Aliso+Viejo,+CA': 112,
#  'Allen,+TX': 134,
#  'Allentown,+PA': 16,
#  'Allison+Park,+PA': 26,
#  'Allston,+MA': 168,
#  'Alpharetta,+GA': 186,
#  'Altamonte+Springs,+FL': 32,
#  'Altoona,+PA': 4,
#  'Ambler,+PA': 127,
#  'Amelia,+LA': 2,
#  'American+Fork,+UT': 82,
#  'Ames,+IA': 5,
#  'Amherst,+NY': 12,
#  'Amherst,+WI': 1,
#  'Anacortes,+WA': 4,
#  'Anaheim+Hills,+CA': 141,
#  'Anaheim,+CA': 208,
#  'Anderson,+IN': 7,
#  'Andover,+MA': 155,
#  'Ankeny,+IA': 8,
#  'Ann+Arbor,+MI': 50,
#  'Annapolis+Junction,+MD': 263,
#  'Annapolis,+MD': 118,
#  'Antioch,+TN': 43,
#  'Apex,+NC': 46,
#  'Apopka,+FL': 34,
#  'Apple+Valley,+MN': 74,
#  'Appleton,+WI': 5,
#  'Ardmore,+PA': 127,
#  'Arlington+Heights,+IL': 244,
#  'Arlington,+MA': 172,
#  'Arlington,+TX': 108,
#  'Arlington,+VA': 342,
#  'Arvada,+CO': 116,
#  'Ashburn,+VA': 309,
#  'Asheville,+NC': 7,
#  'Ashland,+NE': 24,
#  'Astoria,+NY': 310,
#  'Athens,+AL': 21,
#  'Athens,+GA': 3,
#  'Athens,+OH': 1,
#  'Atlanta,+GA': 181,
#  'Atlatna,+GA': 181,
#  'Auburn+Hills,+MI': 80,
#  'Auburn,+MA': 25,
#  'Auburn,+ME': 3,
#  'Auburn,+WA': 106,
#  'Audubon,+PA': 116,
#  'Augusta,+GA': 2,
#  'Aurora,+CO': 96,
#  'Aurora,+IL': 118,
#  'Austell,+GA': 160,
#  'Austin,+TX': 97,
#  'Aventura,+FL': 97,
#  'Avon,+OH': 47,
#  'Bakersfield,+CA': 5,
#  'Baldwin+Park,+CA': 210,
#  'Ballston+Lake,+NY': 16,
#  'Baltimore,+MD': 79,
#  'Bar+Mills,+ME': 10,
#  'Barnstable,+MA': 4,
#  'Barrington,+IL': 146,
#  'Bartlett,+TN': 14,
#  'Batavia,+IL': 124,
#  'Baton+Rouge,+LA': 11,
#  'Battlefield,+MO': 6,
#  'Bay+Head,+NJ': 21,
#  'Beachwood,+OH': 60,
#  'Beaumont,+TX': 2,
#  'Beavercreek,+OH': 19,
#  'Beaverton,+OR': 49,
#  'Beckley,+WV': 1,
#  'Bedford,+NH': 29,
#  'Bedford,+TX': 143,
#  'Bedminster,+NJ': 80,
#  'Bellaire,+TX': 96,
#  'Belle+Haven,+VA': 1,
#  'Bellevue,+WA': 113,
#  'Bellingham,+WA': 4,
#  'Belmar,+NJ': 24,
#  'Belmont,+NH': 4,
#  'Beloit,+WI': 6,
#  'Beltsville,+MD': 361,
#  'Bensenville,+IL': 247,
#  'Berea,+OH': 59,
#  'Bergen,+NY': 21,
#  'Berkeley+Heights,+NJ': 297,
#  'Berkeley,+CA': 172,
#  'Berkeley,+IL': 244,
#  'Bern,+KS': 1,
#  'Berthoud,+CO': 38,
#  'Bessemer,+AL': 21,
#  'Bethel+Park,+PA': 27,
#  'Bethesda,+MD': 349,
#  'Bethlehem,+PA': 19,
#  'Beverly+Hills,+CA': 168,
#  'Beverly,+MA': 153,
#  'Billerica,+MA': 169,
#  'Bingham+Farms,+MI': 88,
#  'Binghamton,+NY': 1,
#  'Birmingham,+AL': 21,
#  'Birmingham,+MI': 82,
#  'Bismarck,+ND': 2,
#  'Black+Creek,+GA': 3,
#  'Blacksburg,+VA': 4,
#  'Blackwood,+NJ': 112,
#  'Blauvelt,+NY': 284,
#  'Blissfield,+MI': 9,
#  'Bloomfield+Hills,+MI': 82,
#  'Bloomingdale,+IL': 245,
#  'Bloomington,+IN': 3,
#  'Bloomington,+MN': 76,
#  'Bloomsburg,+PA': 3,
#  'Blue+Ash,+OH': 58,
#  'Blue+Bell,+PA': 122,
#  'Blue+Earth,+MN': 1,
#  'Blue+Mounds,+WI': 11,
#  'Bluffdale,+UT': 86,
#  'Boca+Raton,+FL': 81,
#  'Boise,+ID': 9,
#  'Bonita+Springs,+FL': 6,
#  'Boothwyn,+PA': 112,
#  'Borden,+IN': 23,
#  'Borger,+TX': 1,
#  'Bossier+City,+LA': 3,
#  'Boston,+MA': 168,
#  'Bothell,+WA': 110,
#  'Boulder,+CO': 98,
#  'Bountiful,+UT': 65,
#  'Bowie,+MD': 262,
#  'Bowling+Green,+KY': 3,
#  'Bowling+Green,+OH': 12,
#  'Boxford,+MA': 146,
#  'Bozeman,+MT': 2,
#  'Bradenton,+FL': 20,
#  'Braintree,+MA': 155,
#  'Brandon,+MS': 5,
#  'Breckenridge,+CO': 1,
#  'Brecksville,+OH': 62,
#  'Breinigsville,+PA': 19,
#  'Bremen,+IN': 9,
#  'Brentwood,+CA': 39,
#  'Brentwood,+MO': 34,
#  'Brentwood,+TN': 42,
#  'Bridgeport,+CT': 43,
#  'Bridgeview,+IL': 229,
#  'Brighton,+MA': 168,
#  'Bristol,+CT': 24,
#  'Broadview+Heights,+OH': 60,
#  'Broken+Arrow,+OK': 14,
#  'Bronx,+NY': 295,
#  'Brookfield,+CT': 24,
#  'Brookfield,+WI': 45,
#  'Brooklyn+Heights,+OH': 63,
#  'Brooklyn+Park,+MN': 76,
#  'Brooklyn,+NY': 318,
#  'Brooksville,+FL': 4,
#  'Broomall,+PA': 132,
#  'Broomfield,+CO': 117,
#  'Brown+Summit,+NC': 13,
#  'Brownsboro,+AL': 21,
#  'Brunswick,+OH': 59,
#  'Bryan,+TX': 1,
#  'Budd+Lake,+NJ': 55,
#  'Buena+Vista,+VA': 1,
#  'Buffalo+Grove,+IL': 241,
#  'Buffalo,+NY': 12,
#  'Buford,+GA': 94,
#  'Buhler,+KS': 1,
#  'Burbank,+CA': 167,
#  'Burien,+WA': 112,
#  'Burke,+VA': 318,
#  'Burlingame,+CA': 231,
#  'Burlington,+MA': 168,
#  'Burlington,+VT': 6,
#  'Burnham,+IL': 152,
#  'Burnsville,+MN': 75,
#  'Burr+Ridge,+IL': 232,
#  'Byron+Center,+MI': 19,
#  'Calabasas,+CA': 147,
#  'Caldwell,+ID': 9,
#  'Calhoun,+GA': 3,
#  'Camarillo,+CA': 34,
#  'Cambridge,+MA': 169,
#  'Camp+Hill,+PA': 8,
#  'Campbell,+CA': 117,
#  'Campbellsport,+WI': 6,
#  'Canastota,+NY': 5,
#  'Canfield,+OH': 3,
#  'Cannon+Falls,+MN': 13,
#  'Canoga+Park,+CA': 147,
#  'Canton,+GA': 104,
#  'Canton,+MI': 85,
#  'Canton,+OH': 6,
#  'Carle+Place,+NY': 282,
#  'Carlsbad,+CA': 30,
#  'Carmel,+IN': 38,
#  'Carmi,+IL': 1,
#  'Carpentersville,+IL': 145,
#  'Carpinteria,+CA': 14,
#  'Carrboro,+NC': 44,
#  'Carrollton,+TX': 147,
#  'Cary,+NC': 45,
#  'Casper,+WY': 1,
#  'Casselberry,+FL': 32,
#  'Castle+Rock,+CO': 81,
#  'Castleton,+NY': 2,
#  'Catonsville,+MD': 125,
#  'Cedar+Falls,+IA': 5,
#  'Cedar+Park,+TX': 97,
#  'Cedar+Rapids,+IA': 11,
#  'Cedarburg,+WI': 45,
#  'Celebration,+FL': 32,
#  'Centennial,+CO': 92,
#  'Center+Harbor,+NH': 3,
#  'Center+Point,+TX': 1,
#  'Centerburg,+OH': 40,
#  'Centreville,+VA': 310,
#  'Century+City,+CA': 167,
#  'Cerritos,+CA': 241,
#  'Chadwick,+IL': 1,
#  'Chagrin+Falls,+OH': 57,
#  'Chalfont,+PA': 128,
#  'Champaign,+IL': 2,
#  'Champlin,+MN': 75,
#  'Chandler,+AZ': 92,
#  'Chanhassen,+MN': 76,
#  'Chantilly,+VA': 311,
#  'Chapel+Hill,+NC': 44,
#  'Charleston,+SC': 17,
#  'Charlestown,+MA': 169,
#  'Charlotte,+NC': 51,
#  'Charlottesville,+VA': 5,
#  'Chatham,+NJ': 294,
#  'Chatsworth,+CA': 138,
#  'Chattanooga,+TN': 7,
#  'Cheektowaga,+NY': 12,
#  'Chelmsford,+MA': 159,
#  'Cherry+Hill,+NJ': 122,
#  'Chesapeake,+VA': 25,
#  'Chester,+PA': 122,
#  'Chester,+VA': 23,
#  'Chesterfield,+MI': 60,
#  'Chesterfield,+MO': 32,
#  'Chevy+Chase,+MD': 351,
#  'Chicago,+IL': 219,
#  'Chino,+CA': 129,
#  'Christiansburg,+VA': 4,
#  'Chula+Vista,+CA': 86,
#  'Cicero,+IL': 237,
#  'Cincinnati,+OH': 55,
#  'Citrus+Heights,+CA': 19,
#  'City+of+Industry,+CA': 223,
#  'Clackamas,+OR': 49,
#  'Claremont,+CA': 118,
#  'Claremore,+OK': 14,
#  'Clarence+Center,+NY': 12,
#  'Clarkesville,+GA': 1,
#  'Clarksville,+MD': 329,
#  'Clarksville,+VA': 1,
#  'Claysville,+PA': 2,
#  'Clayton,+MO': 34,
#  'Clayton,+NC': 33,
#  'Clearwater,+FL': 60,
#  'Cleatwater,+FL': 60,
#  'Cleveland,+MO': 31,
#  'Cleveland,+OH': 61,
#  'Clifton+Park,+NY': 16,
#  'Clinton,+NJ': 67,
#  'Cloverdale,+IN': 2,
#  'Coconut+Creek,+FL': 80,
#  "Coeur+D'+Alene,+ID": 4,
#  'Coeur+D+Alene,+ID': 4,
#  "Coeur+d'Alene,+ID": 4,
#  'Cohoes,+NY': 16,
#  'Colden,+NY': 12,
#  'Colonia,+NJ': 301,
#  'Colorado+Springs,+CO': 3,
#  'Colts+Neck,+NJ': 86,
#  'Columbia,+MD': 248,
#  'Columbia,+MO': 5,
#  'Columbia,+SC': 9,
#  'Columbus,+GA': 1,
#  'Columbus,+IN': 3,
#  'Columbus,+MS': 2,
#  'Columbus,+OH': 42,
#  'Colusa,+CA': 1,
#  'Concord,+CA': 146,
#  'Concord,+NC': 50,
#  'Concord,+NH': 7,
#  'Conroe,+TX': 13,
#  'Conshohocken,+PA': 129,
#  'Conyers,+GA': 117,
#  'Coplay,+PA': 11,
#  'Coppell,+TX': 149,
#  'Coral+Gables,+FL': 65,
#  'Coral+Springs,+FL': 80,
#  'Coralville,+IA': 11,
#  'Corbin,+KY': 1,
#  'Cordova,+TN': 14,
#  'Corona,+CA': 127,
#  'Coronado,+CA': 86,
#  'Corpus+Christi,+TX': 2,
#  'Corte+Madera,+CA': 134,
#  'Corvallis,+OR': 4,
#  'Costa+Mesa,+CA': 133,
#  'Cotati,+CA': 14,
#  'Countryside,+IL': 236,
#  'Coventry,+RI': 20,
#  'Covina,+CA': 184,
#  'Covington,+KY': 55,
#  'Cranberry+Twp,+PA': 27,
#  'Cranbury,+NJ': 86,
#  'Cranston,+RI': 27,
#  'Crest+Hill,+IL': 85,
#  'Crown+Point,+IN': 3,
#  'Culver+City,+CA': 171,
#  'Cumming,+GA': 100,
#  'Cupertino,+CA': 118,
#  'DFW+Airport,+TX': 146,
#  'Dallas,+TX': 138,
#  'Dana+Point,+CA': 115,
#  'Dane,+WI': 11,
#  'Danvers,+MA': 155,
#  'Danville,+CA': 178,
#  'Dardenne+Prairie,+MO': 9,
#  'Davis,+CA': 14,
#  'Dayton,+OH': 19,
#  'Deer+Park,+IL': 146,
#  'Deer+Park,+TX': 89,
#  'Deerfield+Beach,+FL': 83,
#  'Deerfield,+IL': 228,
#  'Delray+Beach,+FL': 72,
#  'Denton,+TX': 88,
#  'Denver,+CO': 114,
#  'Denville,+NJ': 269,
#  'Dequeen,+AR': 1,
#  'Derwood,+MD': 349,
#  'Des+Moines,+IA': 6,
#  'Des+Plaines,+IL': 243,
#  'Detroit,+MI': 79,
#  'Diamond+Bar,+CA': 178,
#  'Doral,+FL': 67,
#  'Dorr,+MI': 19,
#  'Dover,+DE': 1,
#  'Downers+Grove,+IL': 242,
#  'Draper,+UT': 86,
#  'Dripping+Springs,+TX': 95,
#  'Dublin,+CA': 229,
#  'Dublin,+OH': 42,
#  'Dulles,+VA': 311,
#  'Duluth,+GA': 185,
#  'Duluth,+MN': 2,
#  'Dumfries,+VA': 242,
#  'Duncanville,+TX': 132,
#  'Durango,+CO': 1,
#  'Durham,+NC': 45,
#  'Eagan,+MN': 76,
#  'Eagle,+ID': 9,
#  'East+Dubuque,+IL': 2,
#  'East+Dundee,+IL': 139,
#  'East+Greenwich,+RI': 19,
#  'East+Hartford,+CT': 18,
#  'East+Lyme,+CT': 9,
#  'East+Norriton,+PA': 120,
#  'East+Providence,+RI': 31,
#  'East+Stroudsburg,+PA': 10,
#  'East+Windsor,+NJ': 97,
#  'Easton,+MD': 10,
#  'Ebensburg,+PA': 3,
#  'Eden+Prairie,+MN': 76,
#  'Edison,+NJ': 293,
#  'Edmond,+OK': 28,
#  'Effingham,+IL': 2,
#  'El+Cajon,+CA': 90,
#  'El+Dorado+Hills,+CA': 18,
#  'El+Paso,+TX': 1,
#  'El+Segundo,+CA': 171,
#  'El+Segunod,+CA': 171,
#  'Elberton,+GA': 1,
#  'Eldersburg,+MD': 103,
#  'Elgin,+IL': 141,
#  'Elizabethtown,+KY': 1,
#  'Elk+Grove+Village,+IL': 245,
#  'Elk+Grove,+CA': 18,
#  'Elkhart,+IN': 9,
#  'Elkins+Park,+PA': 128,
#  'Elkridge,+MD': 166,
#  'Elkton,+MD': 18,
#  'Ellicott+City,+MD': 168,
#  'Ellisville,+MO': 32,
#  'Elmhurst,+IL': 244,
#  'Emerald+Isle,+NC': 2,
#  'Emeryville,+CA': 174,
#  'Encinitas,+CA': 101,
#  'Encino,+CA': 158,
#  'Enfield,+NH': 1,
#  'Englewood+Cliffs,+NJ': 304,
#  'Englewood,+CO': 114,
#  'Englewood,+NJ': 304,
#  'Enka,+NC': 7,
#  'Erdenheim,+PA': 134,
#  'Erlanger,+KY': 54,
#  'Escondido,+CA': 101,
#  'Euclid,+OH': 56,
#  'Eugene,+OR': 3,
#  'Evanston,+IL': 230,
#  'Everett,+WA': 104,
#  'Ewing,+NJ': 121,
#  'Exeter,+NH': 34,
#  'Exeter,+RI': 16,
#  'Exton,+PA': 103,
#  'Fairbanks,+AK': 2,
#  'Fairborn,+OH': 15,
#  'Fairbury,+NE': 1,
#  'Fairfax,+VA': 318,
#  'Fairfield,+CT': 52,
#  'Fairfield,+NJ': 290,
#  'Fairfield,+OH': 58,
#  'Fairhaven,+MA': 20,
#  'Fairport,+NY': 22,
#  'Falkville,+AL': 1,
#  'Falls+Church,+VA': 339,
#  'Fargo,+ND': 6,
#  'Farmingdale,+NY': 250,
#  'Farmington+Hills,+MI': 88,
#  'Farmington,+CT': 19,
#  'Farmington,+UT': 57,
#  'Fayetteville,+AR': 3,
#  'Fayetteville,+NC': 1,
#  'Ferndale,+WA': 4,
#  'Findlay,+OH': 4,
#  'Fishers,+IN': 38,
#  'Fishkill,+NY': 9,
#  'Flint,+MI': 5,
#  'Floral+Park,+NY': 277,
#  'Florence,+AL': 1,
#  'Florence,+KY': 51,
#  'Florence,+SC': 2,
#  'Florham+Park,+NJ': 294,
#  'Flower+Mound,+TX': 146,
#  'Folsom,+CA': 18,
#  'Foothill+Ranch,+CA': 124,
#  'Forest+Hills,+NY': 299,
#  'Fort+Collins,+CO': 12,
#  'Fort+Lauderdale,+FL': 101,
#  'Fort+Lee,+NJ': 306,
#  'Fort+Mill,+SC': 48,
#  'Fort+Myers,+FL': 4,
#  'Fort+Thomas,+KY': 55,
#  'Fort+Valley,+GA': 3,
#  'Fort+Walton+Beach,+FL': 4,
#  'Fort+Washington,+PA': 127,
#  'Fort+Wayne,+IN': 5,
#  'Fort+Worth,+TX': 48,
#  'Foster+City,+CA': 233,
#  'Fountain+Valley,+CA': 188,
#  'Framingham,+MA': 157,
#  'Frankfort,+KY': 5,
#  'Franklin+park,+IL': 245,
#  'Franklin,+MA': 132,
#  'Franklin,+NJ': 94,
#  'Franklin,+OH': 32,
#  'Franklin,+TN': 42,
#  'Franklin,+WI': 44,
#  'Frederick,+MD': 61,
#  'Fredericksburg,+VA': 9,
#  'Freeport,+NY': 259,
#  'Freeport,+OH': 2,
#  'Fremont,+CA': 229,
#  'Fresno,+CA': 6,
#  'Fridley,+MN': 77,
#  'Frisco,+TX': 137,
#  'Fruita,+CO': 3,
#  'Ft+Lauderdale,+FL': 101,
#  'Ft.+Lauderdale,+FL': 101,
#  'Fullerton,+CA': 215,
#  'Gahanna,+OH': 42,
#  'Gainesville,+FL': 2,
#  'Gaithersburg,+MD': 344,
#  'Galena,+OH': 43,
#  'Gallatin,+TN': 25,
#  'Garden+City,+ID': 9,
#  'Garden+City,+NY': 280,
#  'Garden+Grove,+CA': 206,
#  'Gardena,+CA': 193,
#  'Garland,+TX': 139,
#  'Garner,+NC': 44,
#  'Garnet+Valley,+PA': 112,
#  'Gas+City,+IN': 4,
#  'Geismar,+LA': 11,
#  'Geneva,+IL': 136,
#  'Georgetown,+CT': 43,
#  'Georgetown,+TX': 96,
#  'Germantown,+MD': 341,
#  'Germantown,+WI': 45,
#  'Getzville,+NY': 12,
#  'Gibbsboro,+NJ': 109,
#  'Gibson,+LA': 2,
#  'Gilbert,+AZ': 92,
#  'Gladwyne,+PA': 129,
#  'Glastonbury,+CT': 21,
#  'Glen+Allen,+VA': 23,
#  'Glen+Burnie,+MD': 156,
#  'Glen+Carbon,+IL': 29,
#  'Glen+Ellyn,+IL': 242,
#  'Glen+Rock,+NJ': 285,
#  'Glendale+Heights,+IL': 243,
#  'Glendale,+CA': 170,
#  'Glenview,+IL': 239,
#  'Gloucester+Ciy,+NJ': 129,
#  'Gold+River,+CA': 19,
#  'Golden+Valley,+MN': 77,
#  'Golden,+CO': 116,
#  'Goshen,+NY': 12,
#  'Grand+Junction,+CO': 3,
#  'Grand+Prairie,+TX': 142,
#  'Grand+Rapids,+MI': 19,
#  'Grandview,+WA': 1,
#  'Grandville,+MI': 19,
#  'Granger,+IN': 9,
#  'Grapevine,+TX': 145,
#  'Great+Bend,+KS': 1,
#  'Great+Neck,+NY': 284,
#  'Greenacres,+FL': 51,
#  'Greenbelt,+MD': 346,
#  'Greenbelt,+VA': 346,
#  'Greensboro,+NC': 17,
#  'Greenville,+NC': 2,
#  'Greenville,+SC': 15,
#  'Greenwich,+CT': 281,
#  'Greenwood+Village,+CO': 96,
#  'Greenwood+Villiage,+CO': 96,
#  'Greenwood,+IN': 38,
#  'Greenwood,+SC': 1,
#  'Griffin,+GA': 5,
#  'Guilford,+CT': 18,
#  'Gulf+Breeze,+FL': 3,
#  'Gurnee,+IL': 82,
#  'HIlls,+IA': 3,
#  'Hackensack,+NJ': 301,
#  'Hadley,+MA': 2,
#  'Haiku,+HI': 1,
#  'Hallandale,+FL': 97,
#  'Hamilton,+NJ': 95,
#  'Hamilton,+OH': 60,
#  'Hanahan,+SC': 17,
#  'Harbor+City,+CA': 224,
#  'Harrisburg,+PA': 8,
#  'Hartford,+CT': 19,
#  'Hartland,+WI': 43,
#  'Hasbrouck+Heights,+NJ': 305,
#  'Hastings,+MN': 52,
#  'Hatboro,+PA': 133,
#  'Hattiesburg,+MS': 2,
#  'Hauppauge,+NY': 51,
#  'Hawthorne,+NJ': 288,
#  'Haymarket,+VA': 194,
#  'Hayward,+CA': 230,
#  'Heber+City,+UT': 49,
#  'Hebron,+KY': 54,
#  'Hegins,+PA': 5,
#  'Henderson,+NV': 21,
#  'Hendersonville,+NC': 7,
#  'Hendersonville,+TN': 43,
#  'Henrietta,+NY': 22,
#  'Hermosa+Beach,+CA': 166,
#  'Herndon,+VA': 320,
#  'Hernon+Lake,+MN': 2,
#  'Hewlett,+NY': 267,
#  'Hialeah,+FL': 82,
#  'Hiawatha,+IA': 11,
#  'Hickory+Hills,+IL': 223,
#  'Hickory,+NC': 2,
#  'Hicksville,+NY': 273,
#  'High+Point,+NC': 16,
#  'Highland+Heights,+OH': 56,
#  'Highland+Park,+IL': 221,
#  'Highland+Park,+MI': 82,
#  'Highlands+Ranch,+CO': 92,
#  'Hilliard,+OH': 41,
#  'Hillsboro,+OR': 49,
#  'Hilton+Head+Island,+SC': 3,
#  'Hinsdale,+IL': 240,
#  'Hoboken,+NJ': 316,
#  'Hoffman+Estates,+IL': 245,
#  'Holbrook,+MA': 144,
#  'Holbrook,+NY': 40,
#  'Holland,+MI': 19,
#  'Holland,+OH': 11,
#  'Hollywood,+FL': 97,
#  'Holts+Summit,+MO': 5,
#  'Homewood,+IL': 149,
#  'Honeoye+Falls,+NY': 22,
#  'Honolulu,+HI': 6,
#  'Hoover,+AL': 21,
#  'Hopkinton,+MA': 154,
#  'Horsham,+PA': 133,
#  'Housotn,+TX': 102,
#  'Houston,+TX': 102,
#  'Hudson,+OH': 59,
#  'Hudson,+WI': 54,
#  'Hummelstown,+PA': 14,
#  'Hunt+Valley,+MD': 58,
#  'Huntersville,+NC': 51,
#  'Huntingdon+Valley,+PA': 131,
#  'Huntington+Beach,+CA': 149,
#  'Huntington,+NY': 79,
#  'Huntsville,+AL': 22,
#  'Hyattsville,+MD': 364,
#  'Hyde+Park,+UT': 2,
#  'Idaho+Falls,+ID': 2,
#  'Independence,+OH': 63,
#  'Indiana,+PA': 2,
#  'Indianapolis,+IN': 37,
#  'Inwood,+NY': 304,
#  'Irmo,+SC': 9,
#  'Irvine,+CA': 138,
#  'Irving,+TX': 146,
#  'Irvington,+NY': 281,
#  'Iselin,+NJ': 301,
#  'Isle+of+Palms,+SC': 17,
#  'Itasca,+IL': 246,
#  'Ithaca,+NY': 2,
#  'Jackson,+MI': 1,
#  'Jackson,+MS': 5,
#  'Jackson,+WI': 44,
#  'Jacksonville+Beach,+FL': 27,
#  'Jacksonville,+FL': 26,
#  'Jamaica,+NY': 291,
#  'Jamestown,+ND': 1,
#  'Jamesville,+NY': 4,
#  'Janesville,+WI': 7,
#  'Jeffersonville,+IN': 23,
#  'Jensen+Beach,+FL': 4,
#  'Jersey+City,+NJ': 313,
#  'Jersey+Cty,+NJ': 313,
#  'Jessup,+MD': 248,
#  'Johns+Creek,+GA': 186,
#  'Johnson+City,+TN': 2,
#  'Jonesboro,+AR': 1,
#  'Joplin,+MO': 2,
#  'Jupiter,+FL': 18,
#  'Kailua,+HI': 6,
#  'Kalamazoo,+MI': 4,
#  'Kansas+City,+KS': 35,
#  'Kansas+City,+MO': 36,
#  'Kasnas+City,+MO': 36,
#  'Katy,+TX': 88,
#  'Kaukauna,+WI': 5,
#  'Kennesaw,+GA': 171,
#  'Kenosha,+WI': 20,
#  'Kent,+WA': 111,
#  'Kernersville,+NC': 16,
#  'Ketchum,+ID': 2,
#  'Kettering,+OH': 29,
#  'Killingworth,+CT': 25,
#  'Kimberton,+PA': 102,
#  'King+of+Prussia,+PA': 125,
#  'Kingston,+NH': 53,
#  'Kingwood,+TX': 97,
#  'Kirkland,+WA': 111,
#  'Kissimmee,+FL': 32,
#  'Kitty+Hawk,+NC': 1,
#  'Knightdale,+NC': 40,
#  'Knoxville,+TN': 14,
#  'Kodak,+TN': 13,
#  'La+Crosse,+WI': 5,
#  'La+Grange,+IL': 239,
#  'La+Jolla,+CA': 101,
#  'La+Palma,+CA': 238,
#  'LaGrange,+OH': 44,
#  'Lafayette,+CA': 175,
#  'Lafayette,+CO': 109,
#  'Lafayette,+LA': 7,
#  'Laguna+Hills,+CA': 113,
#  'Laguna+Niguel,+CA': 111,
#  'Lake+Elsinore,+CA': 75,
#  'Lake+Geneva,+WI': 5,
#  'Lake+Havasu+City,+AZ': 1,
#  'Lake+Lure,+NC': 7,
#  'Lake+Orion,+MI': 72,
#  'Lake+Success,+NY': 283,
#  'Lake+Zurich,+IL': 143,
#  'Lake+in+the+Hills,+IL': 121,
#  'Lakeland,+FL': 3,
#  'Lakeville,+MA': 37,
#  'Lakewood+Ranch,+FL': 19,
#  'Lakewood,+CO': 114,
#  'Lakewood,+NJ': 34,
#  'Lambertville,+NJ': 108,
#  'Lancaster,+NY': 12,
#  'Lancaster,+PA': 12,
#  'Land+O+Lakes,+FL': 56,
#  'Landover,+MD': 360,
#  'Langhorne,+PA': 128,
#  'Lanham,+MD': 336,
#  'Lansdowne,+VA': 282,
#  'Lansing,+MI': 5,
#  'Laramie,+WY': 1,
#  'Laredo,+TX': 1,
#  'Largo,+FL': 60,
#  'Larkspur,+CA': 133,
#  'Las+Vegas,+NV': 21,
#  'Latham,+NY': 16,
#  'Laurel,+MD': 299,
#  'Lawrenceville,+GA': 167,
#  'Layton,+UT': 46,
#  'Le+Claire,+IA': 2,
#  'Leavenworth,+KS': 33,
#  'Lebanon,+PA': 18,
#  'Leesburg,+FL': 4,
#  'Leesburg,+VA': 233,
#  'Lehi,+UT': 82,
#  'Lemont+Furnace,+PA': 2,
#  'Lemont,+IL': 215,
#  'Lenexa,+KS': 36,
#  'Lewis+Center,+OH': 42,
#  'Lewiston,+ME': 3,
#  'Lewisville,+TX': 147,
#  'Lexington+Park,+MD': 1,
#  'Lexington,+KY': 5,
#  'Lexington,+MA': 172,
#  'Lexington,+SC': 9,
#  'Liberty,+MO': 33,
#  'Libertyville,+IL': 108,
#  'Lincoln,+NE': 9,
#  'Lincolnshire,+IL': 228,
#  'Lincolnwood,+IL': 233,
#  'Linden,+NJ': 310,
#  'Lindenhurst,+NY': 64,
#  'Lindon,+UT': 51,
#  'Lisle,+IL': 241,
#  'Lititz,+PA': 13,
#  'Little+Chute,+WI': 5,
#  'Little+Falls,+NJ': 302,
#  'Little+Ferry,+NJ': 301,
#  'Little+Rock,+AR': 3,
#  'Littleton,+CO': 96,
#  'Littleton,+MA': 153,
#  'Livermore,+CA': 128,
#  'Livingston,+NJ': 293,
#  'Livonia,+MI': 87,
#  'Lockbourne,+OH': 41,
#  'Logan,+UT': 2,
#  'Lombard,+IL': 244,
#  'Lone+Tree,+CO': 92,
#  'Long+Beach,+CA': 217,
#  'Long+Grove,+IL': 240,
#  'Long+Island+City,+NY': 317,
#  'Longmont,+CO': 45,
#  'Longview,+WA': 1,
#  'Longwood,+FL': 32,
#  'Loomis,+CA': 17,
#  'Lorain,+OH': 41,
#  'Lorton,+VA': 300,
#  'Los+Angeles,+CA': 174,
#  'Los+Gatos,+CA': 97,
#  'Louisville,+CO': 109,
#  'Louisville,+KY': 23,
#  'Loveland,+CO': 34,
#  'Loveland,+OH': 59,
#  'Lovettsville,+VA': 124,
#  'Lowell,+AR': 3,
#  'Lowell,+MA': 159,
#  'Lubbock,+TX': 1,
#  'Lumberton,+NC': 1,
#  'Luray,+VA': 1,
#  'Lyndhurst,+NJ': 308,
#  'Lynnwood,+WA': 108,
#  'Lynwood,+CA': 238,
#  'Mableton,+GA': 175,
#  'Machesney+Park,+IL': 6,
#  'Macon,+GA': 3,
#  'Madison+Heights,+MI': 82,
#  'Madison,+CT': 16,
#  'Madison,+SD': 1,
#  'Madison,+WI': 12,
#  'Mahwah,+NJ': 249,
#  'Maitland,+FL': 32,
#  'Malvern,+AR': 1,
#  'Malvern,+PA': 112,
#  'Manalapan,+NJ': 76,
#  'Manassas,+VA': 295,
#  'Manchester,+CT': 16,
#  'Manchester,+MO': 32,
#  'Manchester,+NH': 23,
#  'Mandeville,+LA': 11,
#  'Manhattan+Beach,+CA': 170,
#  'Manhattan,+KS': 4,
#  'Manistee,+MI': 1,
#  'Manitowoc,+WI': 1,
#  'Mansfield,+MA': 131,
#  'Mansfield,+TX': 80,
#  'Maple+Grove,+MN': 76,
#  'Maple+Lawn,+MD': 328,
#  'Margate,+FL': 80,
#  'Marietta,+GA': 180,
#  'Marion,+IA': 11,
#  'Marion,+IN': 3,
#  'Markle,+IN': 7,
#  'Marlborough,+MA': 148,
#  'Marlow,+OK': 1,
#  'Marlton,+NJ': 114,
#  'Marriottsville,+MD': 120,
#  'Mars,+PA': 27,
#  'Mary+Esther,+FL': 4,
#  'Mason,+OH': 66,
#  'Massapequa,+NY': 247,
#  'Matawan,+NJ': 283,
#  'Matthews,+NC': 49,
#  'Mauldin,+SC': 15,
#  'McFarland,+WI': 13,
#  'McKeesport,+PA': 26,
#  'McKinney,+TX': 71,
#  'McLean,+VA': 341,
#  'Mclean,+VA': 341,
#  'Mebane,+NC': 22,
#  'Mechanicsburg,+PA': 7,
#  'Medford,+NJ': 79,
#  'Media,+PA': 125,
#  'Medina,+MN': 75,
#  'Medina,+OH': 55,
#  'Medley,+FL': 77,
#  'Melbourne,+FL': 2,
#  'Melrose+Park,+IL': 243,
#  'Melville,+NY': 87,
#  'Memphis,+TN': 14,
#  'Menands,+NY': 16,
#  'Menlo+Park,+CA': 221,
#  'Menomonee+Falls,+WI': 44,
#  'Mentor,+OH': 43,
#  'Mercer+Island,+WA': 113,
#  'Meridian,+ID': 9,
#  'Merion+Station,+PA': 128,
#  'Merriam,+KS': 36,
#  'Mesa,+AZ': 92,
#  'Mesquite,+NV': 1,
#  'Mesquite,+TX': 132,
#  'Metairie,+LA': 12,
#  'Miami+beach,+FL': 66,
#  'Miami,+FL': 67,
#  'Miamisburg,+OH': 33,
#  'Michigan+City,+IN': 1,
#  'Middleburg+Hts,+OH': 60,
#  'Middleburg,+VA': 138,
#  'Middlebury,+CT': 28,
#  'Middleton,+MA': 157,
#  'Middletown,+CT': 28,
#  'Middletown,+PA': 12,
#  'Middletown,+RI': 19,
#  'Midland,+MI': 2,
#  'Midway,+KY': 5,
#  'Midwest+City,+OK': 28,
#  'Milford,+CT': 39,
#  'Milford,+MA': 135,
#  'Milford,+MI': 83,
#  'Millersville,+MD': 219,
#  'Millington,+TN': 14,
#  'Milpitas,+CA': 124,
#  'Milton,+NH': 5,
#  'Milwaukee,+WI': 44,
#  'Milwuakie,+OR': 49,
#  'Minneapolis,+MN': 78,
#  'Minnetonka,+MN': 76,
#  'Minooka,+IL': 35,
#  'Miramar+Beach,+FL': 4,
#  'Miramar,+FL': 97,
#  'Mishawaka,+IN': 9,
#  'Mission+Viejo,+CA': 116,
#  'Missoula,+MT': 2,
#  'Mobile,+AL': 4,
#  'Modesto,+CA': 4,
#  'Mohnton,+PA': 17,
#  'Monett,+MO': 2,
#  'Monmouth+Junction,+NJ': 90,
#  'Monroe,+NC': 46,
#  'Monroe,+OH': 61,
#  'Monsey,+NY': 256,
#  'Montebello,+CA': 236,
#  'Monterey,+CA': 5,
#  'Montgomery,+AL': 2,
#  'Montgomery,+IL': 109,
#  'Montvale,+NJ': 278,
#  'Moorestown,+NJ': 120,
#  'Mooresville,+NC': 47,
#  'Moorpark,+CA': 55,
#  'Moraine,+OH': 25,
#  'Morgantown,+WV': 2,
#  'Morganville,+NJ': 102,
#  'Morristown,+NJ': 290,
#  'Morrisville,+NC': 45,
#  'Morton+Grove,+IL': 239,
#  'Moscow,+ID': 1,
#  'Mosheim,+TN': 1,
#  'Mount+Airy,+MD': 128,
#  'Mount+Airy,+NC': 2,
#  'Mount+Laurel,+NJ': 114,
#  'Mount+Pleasant,+SC': 17,
#  'Mount+Vernon,+MO': 6,
#  'Mount+Vernon,+OH': 9,
#  'Mountain+Brook,+AL': 21,
#  'Mountain+View,+CA': 129,
#  'Mountainside,+NJ': 306,
#  'Mt.+Laurel,+NJ': 114,
#  'Mt.+Pleasant,+SC': 17,
#  'Mt.+Sterling,+IL': 1,
#  'Mundelein,+IL': 120,
#  'Murray,+UT': 85,
#  'Murrells+Inlet,+SC': 2,
#  'Murrieta,+CA': 35,
#  'N+Lakewood,+WA': 8,
#  'N.+Charleston,+SC': 17,
#  'N.+Hollywood,+CA': 165,
#  'Naperville,+IL': 235,
#  'Naples,+FL': 4,
#  'Nashua,+NH': 68,
#  'Nashville,+IN': 6,
#  'Nashville,+TN': 43,
#  'Natick,+MA': 164,
#  'Needham,+MA': 172,
#  'New+Albany,+IN': 23,
#  'New+Albany,+OH': 43,
#  'New+Berlin,+WI': 43,
#  'New+Brunswick,+NJ': 286,
#  'New+Castle,+DE': 56,
#  'New+Castle,+PA': 5,
#  'New+Glarus,+WI': 10,
#  'New+Haven,+CT': 28,
#  'New+Kensington,+PA': 26,
#  'New+London,+CT': 6,
#  'New+Orleans,+LA': 12,
#  'New+Port+Richey,+FL': 55,
#  'New+Windsor,+NY': 17,
#  'New+York+City,+NY': 316,
#  'New+York,+NY': 316,
#  'Newark,+CA': 228,
#  'Newark,+DE': 31,
#  'Newark,+NJ': 314,
#  'Newberry,+FL': 2,
#  'Newbury,+OH': 48,
#  'Newburyport,+MA': 64,
#  'Newington,+NH': 15,
#  'Newport+Beach,+CA': 131,
#  'Newport+News,+VA': 11,
#  'Newport,+KY': 55,
#  'Newport,+RI': 17,
#  'Newton,+MA': 168,
#  'Newtown+Square,+PA': 130,
#  'Newtown,+PA': 130,
#  'Niles,+IL': 242,
#  'Norcross,+GA': 188,
#  'Norfolk,+NE': 2,
#  'Norfolk,+VA': 25,
#  'Norman,+OK': 28,
#  'Norristown,+PA': 127,
#  'North+Andover,+MA': 147,
#  'North+Bethesda,+MD': 352,
#  'North+Brunswick,+NJ': 100,
#  'North+Charleston,+SC': 17,
#  'North+Eastham,+MA': 3,
#  'North+Kansas+City,+MO': 35,
#  'North+Las+Vegas,+NV': 21,
#  'North+Little+Rock,+AR': 3,
#  'North+Miami+Beach,+FL': 85,
#  'North+Palm+Beach,+FL': 21,
#  'North+Pole,+AK': 2,
#  'North+Salt+Lake,+UT': 65,
#  'North+Wales,+PA': 127,
#  'Northampton,+MA': 2,
#  'Northborough,+MA': 134,
#  'Northbrook,+IL': 238,
#  'Northridge,+CA': 150,
#  'Northville,+MI': 87,
#  'Norwalk,+CA': 235,
#  'Norwalk,+CT': 67,
#  'Norwell,+MA': 127,
#  'Norwood,+MA': 164,
#  'Novato,+CA': 110,
#  'Novi,+MI': 87,
#  'Nyack,+NY': 274,
#  "O'Fallon,+IL": 28,
#  'Oak+Brook,+IL': 242,
#  'Oak+Harbor,+OH': 8,
#  'Oak+Park,+IL': 242,
#  'Oak+Park,+MI': 82,
#  'Oak+Ridge,+TN': 13,
#  'Oakbrook+Terrace,+IL': 244,
#  'Oakbrook+terrace,+IL': 244,
#  'Oakland+Gardens,+NY': 280,
#  'Oakland,+CA': 179,
#  'Oakwood+Village,+OH': 19,
#  'Ocean,+NJ': 48,
#  'Oceanside,+CA': 31,
#  'Ogden,+UT': 11,
#  'Okemos,+MI': 5,
#  'Oklahoma+City,+OK': 28,
#  'Olathe,+KS': 32,
#  'Old+Lyme,+CT': 10,
#  'Oldsmar,+FL': 61,
#  'Olney,+IL': 1,
#  'Olney,+MD': 364,
#  'Omaha,+NE': 16,
#  'Oneonta,+NY': 1,
#  'Ontario,+CA': 116,
#  'Ontario,+NY': 21,
#  'Ooltewah,+TN': 7,
#  'Oradell,+NJ': 288,
#  'Orange+Park,+FL': 26,
#  'Orange,+CA': 197,
#  'Orangeburg,+NY': 284,
#  'Oregon+City,+OR': 49,
#  'Orem,+UT': 49,
#  'Orinda,+CA': 176,
#  'Orlando,+FL': 32,
#  'Orrville,+OH': 10,
#  'Osceola,+WI': 2,
#  'Oshkosh,+WI': 5,
#  'Osterville,+MA': 5,
#  'Otsego,+MN': 56,
#  'Overland+Park,+KS': 36,
#  'Owatonna,+MN': 1,
#  'Owings+Mills,+MD': 74,
#  'Owings,+MD': 116,
#  'Owosso,+MI': 6,
#  'Oxford,+MS': 3,
#  'Oxnard,+CA': 20,
#  'Oxon+Hill,+MD': 339,
#  'Ozark,+MO': 5,
#  'PIttsburgh,+PA': 26,
#  'Palisade,+CO': 3,
#  'Palm+Bay,+FL': 3,
#  'Palm+Beach+Gardens,+FL': 21,
#  'Palm+Desert,+CA': 2,
#  'Palm+Harbor,+FL': 60,
#  'Palo+Alto,+CA': 217,
#  'Panama+City,+FL': 1,
#  'Paramount,+CA': 231,
#  'Parkland,+FL': 77,
#  'Parlin,+NJ': 294,
#  'Parsippany,+NJ': 290,
#  'Pasadena,+CA': 177,
#  'Pasadena,+TX': 93,
#  'Paso+Robles,+CA': 7,
#  'Pawleys+Island,+SC': 2,
#  'Pawtucket,+RI': 50,
#  'Payson,+AZ': 1,
#  'Peabody,+MA': 156,
#  'Peachtree+City,+GA': 83,
#  'Pearland,+TX': 89,
#  'Pelham,+AL': 21,
#  'Pembroke+Pines,+FL': 97,
#  'Pensacola,+FL': 3,
#  'Peoria,+IL': 4,
#  'Petaluma,+CA': 16,
#  'Pewaukee,+WI': 44,
#  'Pflugerville,+TX': 96,
#  'Philadelphia,+PA': 130,
#  'Philipsburg,+PA': 5,
#  'Phoenix,+AZ': 92,
#  'Phoenix,+OR': 1,
#  'Phoenixville,+PA': 111,
#  'Pico+Rivera,+CA': 233,
#  'Piketon,+OH': 2,
#  'Pine+Grove,+PA': 10,
#  'Piscataway,+NJ': 288,
#  'Pittsboro,+NC': 27,
#  'Pittsburgh,+PA': 26,
#  'Pittsford,+NY': 22,
#  'Placentia,+CA': 198,
#  'Plainfield,+IL': 102,
#  'Plainsboro,+NJ': 91,
#  'Plainview,+NY': 260,
#  'Plainville,+CT': 26,
#  'Plaistow,+NH': 82,
#  'Plano,+TX': 138,
#  'Plantation,+FL': 101,
#  'Pleasant+Grove,+UT': 82,
#  'Pleasant+Hill,+MO': 32,
#  'Pleasant+Ridge,+MI': 82,
#  'Pleasant+Valley,+NY': 6,
#  'Pleasanton,+CA': 154,
#  'Pleasantville,+NY': 87,
#  'Plymouth+Meeting,+PA': 130,
#  'Plymouth,+MA': 22,
#  'Plymouth,+MI': 85,
#  'Plymouth,+MN': 76,
#  'Pompano+Beach,+FL': 74,
#  'Pompton+Plains,+NJ': 281,
#  'Ponte+Vedra,+FL': 27,
#  'Port+Chester,+NY': 289,
#  'Port+Matilda,+PA': 5,
#  'Port+Orange,+FL': 1,
#  'Port+Washington,+WI': 39,
#  'Portage,+MI': 4,
#  'Portage,+OH': 12,
#  'Portland,+ME': 9,
#  'Portland,+OR': 49,
#  'Portola+Valley,+CA': 202,
#  'Portsmouth,+NH': 14,
#  'Portsmouth,+VA': 25,
#  'Potomac+Falls,+VA': 322,
#  'Poway,+CA': 101,
#  'Powder+Springs,+GA': 158,
#  'Powell,+OH': 42,
#  'Prescott+Valley,+AZ': 1,
#  'Princeton,+IN': 2,
#  'Princeton,+NJ': 86,
#  'Providence,+RI': 30,
#  'Provo,+UT': 47,
#  'Punta+Gorda,+FL': 3,
#  'Puyallup,+WA': 90,
#  'Quincy,+MA': 159,
#  'Racine,+WI': 34,
#  'Radnor,+PA': 126,
#  'Raleigh,+NC': 44,
#  'Ramsey,+MN': 62,
#  'Ramsey,+NJ': 270,
#  'Rancho+Cordova,+CA': 19,
#  'Rancho+Cucamonga,+CA': 50,
#  'Rancho+Santa+Margarita,+CA': 119,
#  'Randolph,+MA': 155,
#  'Reading,+PA': 20,
#  'Red+Bank,+NJ': 258,
#  'Redding,+CT': 38,
#  'Redmond,+WA': 111,
#  'Redondo+Beach,+CA': 161,
#  'Redwood+City,+CA': 223,
#  'Reno,+NV': 4,
#  'Rensselaer,+NY': 14,
#  'Renton,+WA': 112,
#  'Reston,+VA': 321,
#  'Rexburg,+ID': 2,
#  'Richardson,+TX': 140,
#  'Richfield,+OH': 59,
#  'Richmond,+CA': 145,
#  'Richmond,+VA': 23,
#  'Ridgeland,+MS': 5,
#  'River+Falls,+WI': 16,
#  'Riverbank,+CA': 4,
#  'Riverside,+CA': 76,
#  'Riverview,+FL': 57,
#  'Roanoke,+VA': 4,
#  'Robbinsville,+NJ': 102,
#  'Rochelle+Park,+NJ': 298,
#  'Rochester+Hills,+MI': 82,
#  'Rochester,+MN': 2,
#  'Rochester,+NY': 22,
#  'Rock+Hill,+NY': 5,
#  'Rock+Island,+IL': 2,
#  'Rockaway,+NJ': 261,
#  'Rockford,+IL': 6,
#  'Rockford,+MN': 61,
#  'Rockland,+MA': 138,
#  'Rocklin,+CA': 18,
#  'Rockville,+MD': 353,
#  'Rockville,+VA': 23,
#  'Rogers,+MN': 67,
#  'Rolling+Hills+Estate,+CA': 178,
#  'Rolling+Meadowns,+IL': 245,
#  'Rolling+Meadows,+IL': 245,
#  'Rome,+GA': 3,
#  'Ronkonkoma,+NY': 40,
#  'Rosemont,+IL': 244,
#  'Roseville,+CA': 19,
#  'Roseville,+MN': 79,
#  'Roslyn+Heights,+NY': 286,
#  'Roswell,+GA': 186,
#  'Rushville,+IN': 1,
#  'Ruston,+LA': 2,
#  'Rutherford,+NJ': 309,
#  'Sacramento,+CA': 19,
#  'Saginaw,+MI': 2,
#  'Saint+Charles,+MO': 33,
#  'Saint+Louis,+MO': 33,
#  'Saint+Marys,+KS': 4,
#  'Saint+Paul,+MN': 77,
#  'Saint+Petersburg,+FL': 61,
#  'Saint+Pettersburg,+FL': 61,
#  'Saint+Simons+Island,+GA': 2,
#  'Salem,+MA': 155,
#  'Salem,+NH': 95,
#  'Salem,+OR': 5,
#  'Salina,+KS': 1,
#  'Salinas,+CA': 5,
#  'Salisbury,+MA': 63,
#  'Salisbury,+NC': 8,
#  'Salt+Lake+City,+UT': 76,
#  'Salt+Lake,+UT': 76,
#  'San+Antoniio,+TX': 23,
#  'San+Antonio,+TX': 23,
#  'San+Bernardino,+CA': 12,
#  'San+Bruno,+CA': 190,
#  'San+Carlos,+CA': 229,
#  'San+Clemente,+CA': 107,
#  'San+Diego,+CA': 90,
#  'San+Dimas,+CA': 166,
#  'San+Francisco,+CA': 165,
#  'San+Gabriel,+CA': 183,
#  'San+Jose,+CA': 116,
#  'San+Juan,+PR': 1,
#  'San+Leandro,+CA': 216,
#  'San+Luis+Obispo,+CA': 7,
#  'San+Marcos,+CA': 102,
#  'San+Marino,+CA': 177,
#  'San+Mateo,+CA': 227,
#  'San+Rafael,+CA': 122,
#  'San+Ramon,+CA': 207,
#  'Sandwich,+IL': 25,
#  'Sandy+Springs,+GA': 187,
#  'Sandy,+UT': 86,
#  'Sanford,+NC': 7,
#  'Santa+Ana,+CA': 144,
#  'Santa+Barbara,+CA': 12,
#  'Santa+Clara,+CA': 123,
#  'Santa+Clarita,+CA': 123,
#  'Santa+Cruz,+CA': 59,
#  'Santa+Fe+Springs,+CA': 233,
#  'Santa+Monica,+CA': 165,
#  'Santa+Rosa,+CA': 7,
#  'Santa+ana,+CA': 144,
#  'Santee,+CA': 91,
#  'Sarasota,+FL': 12,
#  'Saratoga+Springs,+NY': 15,
#  'Saratoga,+CA': 111,
#  'Saugus,+MA': 163,
#  'Sauk+Rapids,+MN': 3,
#  'Sausalito,+CA': 150,
#  'Savannah,+GA': 4,
#  'Scarsdale,+NY': 286,
#  'Schaumburg,+IL': 246,
#  'Schenectady,+NY': 16,
#  'Schertz,+TX': 23,
#  'Schiller+Park,+IL': 247,
#  'Schuamburg,+IL': 246,
#  'Scottsdale,+AZ': 92,
#  'Scranton,+PA': 1,
#  'Seabrook,+NH': 40,
#  'Seaford,+DE': 3,
#  'Seaside,+CA': 5,
#  'Seatle,+WA': 113,
#  'Seattle,+WA': 113,
#  'Secaucus,+NJ': 311,
#  'Selbyville,+DE': 2,
#  'Sharon+Hill,+PA': 132,
#  'Sharon,+MA': 149,
#  'Sharon,+PA': 3,
#  'Shaumburg,+IL': 246,
#  'Shawnee,+KS': 36,
#  'Sheffield+Village,+OH': 44,
#  'Shelby+Twp,+MI': 75,
#  'Shelton,+CT': 34,
#  'Sherman+Oaks,+CA': 164,
#  'Short+Hills,+NJ': 296,
#  'Shreveport,+LA': 3,
#  'Shrewsbury,+NJ': 257,
#  'Sierra+Madre,+CA': 164,
#  'Silver+Spring,+MD': 354,
#  'Simi+Valley,+CA': 76,
#  'Singer+Island,+FL': 32,
#  'Sioux+Falls,+SD': 1,
#  'Skillman,+NJ': 88,
#  'Slater,+IA': 8,
#  'Smyrna,+GA': 177,
#  'So.+Burlington,+VT': 6,
#  'Solana+Beach,+CA': 101,
#  'Solon,+OH': 59,
#  'Somerset,+NJ': 92,
#  'Somerville,+MA': 169,
#  'South+Barrington,+IL': 151,
#  'South+Bend,+IN': 9,
#  'South+Burlington,+VT': 6,
#  'South+Easton,+MA': 126,
#  'South+El+Monte,+CA': 228,
#  'South+Jordan,+UT': 86,
#  'South+Ogden,+UT': 11,
#  'South+Plainfield,+NJ': 297,
#  'South+San+Francisco,+CA': 189,
#  'South+Windsor,+CT': 15,
#  'Southampton,+PA': 132,
#  'Southborough,+MA': 148,
#  'Southern+Pines,+NC': 4,
#  'Southfield,+MI': 88,
#  'Southfileld,+MI': 88,
#  'Southlake,+TX': 145,
#  'Sparta,+WI': 5,
#  'Spartanburg,+SC': 15,
#  'Spearfish,+SD': 1,
#  'Spirit+lake,+IA': 2,
#  'Spokane+Valley,+WA': 5,
#  'Spokane,+WA': 2,
#  'Spring+Hill,+FL': 6,
#  'Spring,+TX': 96,
#  'Springfield,+IL': 1,
#  'Springfield,+MO': 6,
#  'Springfield,+VA': 315,
#  'Springville,+UT': 36,
#  'St+Charles,+IL': 141,
#  'St+James,+NY': 46,
#  'St+Louis+Park,+MN': 77,
#  'St+Petersburgh,+FL': 61,
#  'St.+Augustine,+FL': 4,
#  'St.+Charles,+IL': 141,
#  'St.+Cloud,+MN': 3,
#  'St.+Louis+Park,+MN': 77,
#  'St.+Louis,+MO': 33,
#  'St.+Paul,+MN': 77,
#  'St.+Petersburg,+FL': 61,
#  'St.+Rose,+LA': 10,
#  'St.+Simons+Island,+GA': 2,
#  'Stafford,+TX': 90,
#  'Stafford,+VA': 36,
#  'Stamford,+CT': 91,
#  'Starkville,+MS': 2,
#  'State+College,+PA': 4,
#  'Staten+Island,+NY': 310,
#  'Statesville,+NC': 8,
#  'Staunton,+VA': 1,
#  'Sterling+Heights,+MI': 82,
#  'Sterling,+VA': 319,
#  'Stevensville,+MD': 42,
#  'Stillwater,+OK': 1,
#  'Stone+Mountain,+GA': 185,
#  'Stoneham,+MA': 167,
#  'Stoughton,+MA': 151,
#  'Strongsville,+OH': 58,
#  'Stuart,+FL': 5,
#  'Suffolk,+VA': 11,
#  'Sugar+Land,+TX': 89,
#  'Sugarcreek,+OH': 5,
#  'Summerville,+SC': 17,
#  'Sun+Prairie,+WI': 10,
#  'Sun+Valley,+CA': 161,
#  'Sunnyvale,+CA': 129,
#  'Sunrise,+FL': 98,
#  'Sussex,+NJ': 20,
#  'Sussex,+WI': 44,
#  'Suwanee,+GA': 179,
#  'Sweetwater,+TN': 1,
#  'Sylvania,+OH': 11,
#  'Syosset,+NY': 272,
#  'Syracuse,+NE': 9,
#  'Syracuse,+NY': 4,
#  'Tacoma,+WA': 90,
#  'Tallahassee,+FL': 3,
#  'Tallayassee,+FL': 3,
#  'Tamarac,+FL': 98,
#  'Tampa,+FL': 61,
#  'Taos,+NM': 1,
#  'Tarpon+Springs,+FL': 61,
#  'Tarrytown,+NY': 278,
#  'Taunton,+MA': 50,
#  'Taylor,+MI': 82,
#  'Temecula,+CA': 21,
#  'Tempe,+AZ': 92,
#  'Terre+Haute,+IN': 1,
#  'Texas,+TX': 1,
#  'The+Villages,+FL': 3,
#  'The+Woodlands,+TX': 91,
#  'Thermal,+CA': 2,
#  'Thonotosassa,+FL': 55,
#  'Thousand+Oaks,+CA': 79,
#  'Toledo,+IL': 2,
#  'Toledo,+OH': 12,
#  'Tomball,+TX': 95,
#  'Toms+River,+NJ': 18,
#  'Topsfield,+MA': 150,
#  'Torrance,+CA': 185,
#  'Torrington,+CT': 17,
#  'Towson,+MD': 66,
#  'Tracy,+CA': 20,
#  'Traverse+City,+MI': 3,
#  'Trenton,+NJ': 113,
#  'Trevose,+PA': 131,
#  'Trinity,+FL': 61,
#  'Troy,+MI': 82,
#  'Troy,+NY': 16,
#  'Troy,+OH': 14,
#  'Trumbull,+CT': 34,
#  'Tualatin,+OR': 49,
#  'Tucker,+GA': 184,
#  'Tucson,+AZ': 5,
#  'Tukwila,+WA': 112,
#  'Tulsa,+OK': 14,
#  'Turlock,+CA': 3,
#  'Tustin,+CA': 143,
#  'Twinsburg,+OH': 59,
#  'Tyler,+TX': 2,
#  "Tyson's+Corner,+VA": 340,
#  'Tysons+Corner,+VA': 340,
#  'Union+City,+CA': 230,
#  'Uniondale,+NY': 266,
#  'Urbana,+IA': 10,
#  'Urbandale,+IA': 8,
#  'Utica,+NY': 2,
#  'Vail,+AZ': 5,
#  'Valdosta,+GA': 1,
#  'Valencia,+CA': 124,
#  'Valley+City,+ND': 1,
#  'Valley+Forge,+PA': 114,
#  'Valley+View,+OH': 62,
#  'Valley+Village,+CA': 170,
#  'Van+Nuys,+CA': 160,
#  'Vancouver,+WA': 49,
#  'Venice,+CA': 167,
#  'Vernon+Hills,+IL': 127,
#  'Vernon,+CA': 186,
#  'Vero+Beach,+FL': 3,
#  'Victor,+NY': 22,
#  'Vienna,+VA': 323,
#  'Villa+Park,+IL': 244,
#  'Vincennes,+IN': 2,
#  'Vineburg,+CA': 18,
#  'Virginia+Beach,+VA': 22,
#  'Vista,+CA': 31,
#  'Volo,+IL': 86,
#  'Waite+Park,+MN': 3,
#  'Wakarusa,+IN': 9,
#  'Wakefield,+MA': 167,
#  'Walden,+NY': 7,
#  'Wall+Township,+NJ': 30,
#  'Wall,+NJ': 30,
#  'Walla+Walla,+WA': 1,
#  'Wallingford,+CT': 28,
#  'Walnut+Creek,+CA': 167,
#  'Walpole,+MA': 155,
#  'Waltham,+MA': 171,
#  'Warren,+MI': 81,
#  'Warren,+NJ': 290,
#  'Warrenton,+VA': 113,
#  'Warrenville,+IL': 238,
#  'Warrington,+PA': 129,
#  'Warwick,+RI': 23,
#  'Washington+Township,+NJ': 103,
#  'Washington,+DC': 348,
#  'Washingtonton,+DC': 348,
#  'Waterford,+MI': 77,
#  'Waterloo,+IA': 5,
#  'Watertown,+CT': 24,
#  'Watsontown,+PA': 2,
#  'Watsonville,+CA': 12,
#  'Waukegan,+IL': 81,
#  'Waukesha,+WI': 43,
#  'Wausau,+WI': 1,
#  'Wauwatosa,+WI': 45,
#  'Waverly,+OH': 2,
#  'Waxhaw,+NC': 45,
#  'Wayland,+IA': 2,
#  'Wayland,+MA': 172,
#  'Wayne,+NE': 2,
#  'Wayne,+PA': 125,
#  'Wayzata,+MN': 76,
#  'Webb+City,+MO': 2,
#  'Wellesley,+MA': 173,
#  'Wellington,+FL': 45,
#  'West+Allis,+WI': 45,
#  'West+Bend,+WI': 28,
#  'West+Chester,+OH': 60,
#  'West+Chester,+PA': 97,
#  'West+Chicago,+IL': 243,
#  'West+Columbia,+SC': 9,
#  'West+Des+Moines,+IA': 6,
#  'West+Hartford,+CT': 19,
#  'West+Hills,+CA': 140,
#  'West+Hollywood,+CA': 170,
#  'West+Islip,+NY': 47,
#  'West+Jordan,+UT': 86,
#  'West+Monroe,+LA': 2,
#  'West+Palm+Beach,+FL': 34,
#  'West+Sacramento,+CA': 19,
#  'West+Salem,+WI': 5,
#  'West+Trenton,+NJ': 123,
#  'West+Valley+City,+UT': 79,
#  'West+Windsor,+NJ': 98,
#  'Westampton,+NJ': 105,
#  'Westborough,+MA': 134,
#  'Westbury,+NY': 278,
#  'Westchester,+IL': 242,
#  'Westerville,+OH': 43,
#  'Westford,+MA': 159,
#  'Westlake+Ohio,+OH': 57,
#  'Westlake+Village,+CA': 86,
#  'Westlake,+OH': 57,
#  'Westland,+MI': 85,
#  'Westminster,+CA': 213,
#  'Westminster,+CO': 116,
#  'Westminster,+MD': 50,
#  'Weston,+FL': 97,
#  'Westport,+CT': 59,
#  'Westwood,+NJ': 284,
#  'Weymouth,+MA': 149,
#  'Wheaton,+IL': 243,
#  'White+Oak,+TX': 2,
#  'White+Plains,+NY': 285,
#  'Whiting,+ME': 1,
#  'Wichita,+KS': 6,
#  'Williamston,+MI': 5,
#  'Willoughby,+OH': 52,
#  'Willow+Grove,+PA': 133,
#  'Wilmette,+IL': 232,
#  'Wilmington,+DE': 83,
#  'Wilmington,+MA': 169,
#  'Wilmington,+NC': 2,
#  'Wilsonville,+OR': 52,
#  'Wilton,+CT': 51,
#  'Winchester,+VA': 3,
#  'Winder,+GA': 48,
#  'Windsor+Mill,+MD': 114,
#  'Winfield,+KS': 1,
#  'Winnetka,+CA': 150,
#  'Winooski,+VT': 6,
#  'Winston+Salem,+NC': 15,
#  'Winston-Salem,+NC': 15,
#  'Winter+Park,+FL': 32,
#  'Winter+Springs,+FL': 32,
#  'Winterville,+NC': 2,
#  'Wixom,+MI': 87,
#  'Woburn,+MA': 170,
#  'Woodbine,+MD': 117,
#  'Woodbridge,+NJ': 305,
#  'Woodbridge,+VA': 298,
#  'Woodbury,+MN': 75,
#  'Woodbury,+NJ': 125,
#  'Woodhaven,+NY': 291,
#  'Woodinville,+WA': 110,
#  'Woodland+Hills,+CA': 147,
#  'Woods+Cross,+UT': 65,
#  'Woodstock,+GA': 184,
#  'Woodstock,+IL': 45,
#  'Woodville,+WI': 3,
#  'Woodward,+OK': 2,
#  'Worcester,+MA': 32,
#  'Worthington,+OH': 42,
#  'Wyomissing,+PA': 17,
#  'Yonkers,+NY': 295,
#  'Youngsville,+LA': 7,
#  'Yukon,+OK': 28,
#  'Zumbrota,+MN': 3,
#  'asheville,+NC': 7,
#  'bellevue,+WA': 113,
#  'charlotte,+NC': 51,
#  'iselin,+NJ': 301,
#  'lake+placid,+FL': 1,
#  'lake+worth,+FL': 50,
#  'lansing,+MI': 5,
#  'las+vegas,+NV': 21,
#  'lawrence,+MA': 147,
#  'leesburg,+VA': 233,
#  'long+beach,+CA': 217,
#  'pompano+beach,+FL': 74,
#  'scotch+plains,+NJ': 301,
#  'washington,+NJ': 34,
#  'wilmington,+DE': 83}

# %%
b_df = DataFrame.from_dict(num_businesses_in_r_range, orient='index' )

# %%
b_df.sort(columns=0, ascending=False ).head(n=60)
# Out:
#                          0
# Hyattsville,+MD        364
# Olney,+MD              364
# Beltsville,+MD         361
# Landover,+MD           360
# Silver+Spring,+MD      354
# Rockville,+MD          353
# North+Bethesda,+MD     352
# Chevy+Chase,+MD        351
# Bethesda,+MD           349
# Derwood,+MD            349
# Washingtonton,+DC      348
# Washington,+DC         348
# Greenbelt,+MD          346
# Greenbelt,+VA          346
# Gaithersburg,+MD       344
# Arlington,+VA          342
# Mclean,+VA             341
# Germantown,+MD         341
# McLean,+VA             341
# Tyson's+Corner,+VA     340
# Tysons+Corner,+VA      340
# Falls+Church,+VA       339
# Oxon+Hill,+MD          339
# Alexandria,+VA         336
# Lanham,+MD             336
# Clarksville,+MD        329
# Maple+Lawn,+MD         328
# Vienna,+VA             323
# Potomac+Falls,+VA      322
# Reston,+VA             321
# Herndon,+VA            320
# Sterling,+VA           319
# Burke,+VA              318
# Fairfax,+VA            318
# Brooklyn,+NY           318
# Long+Island+City,+NY   317
# New+York,+NY           316
# Hoboken,+NJ            316
# New+York+City,+NY      316
# Springfield,+VA        315
# Newark,+NJ             314
# Jersey+City,+NJ        313
# Jersey+Cty,+NJ         313
# Secaucus,+NJ           311
# Dulles,+VA             311
# Chantilly,+VA          311
# Linden,+NJ             310
# Centreville,+VA        310
# Astoria,+NY            310
# Staten+Island,+NY      310
# Rutherford,+NJ         309
# Ashburn,+VA            309
# Lyndhurst,+NJ          308
# Fort+Lee,+NJ           306
# Mountainside,+NJ       306
# Woodbridge,+NJ         305
# Hasbrouck+Heights,+NJ  305
# Inwood,+NY             304
# Englewood+Cliffs,+NJ   304
# Englewood,+NJ          304

# %%
b_df.columns = ['Numbers of INC 5000 in 30 Miles']

# %%
test = 'Hyattsville,+MD'

# %%
entry = df[df['coded_city_state'] == test]
entry.ix[entry.first_valid_index()]
# Out:
# 'Hyattsville'

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}
state_code = {v:k for k, v in states.items()}

# %%
old_result_set = r"C:\Users\Schuster\Documents\GitHub\data-science-new-job-locations\linkedin_ds_jobs\result_set.csv"
result_df = DataFrame.from_csv(old_result_set, index_col=None )

# %%
result_df['state_code'] = [ state_code[full_state] for full_state in result_df['state']]
result_df['city_state'] = result_df['city'] + ', ' + result_df['state_code']
result_df['coded_city_state'] = [re.sub(' ', '+', place) for place in result_df['city_state']]

# %%
busi_df = result_df.merge(b_df, left_on=result_df['coded_city_state'], right_on=b_df.index)
business_df = busi_df[['city', 'state', 'Numbers of Cities in 30 Miles', 'coded_city_state']]
business_df.columns = ['city', 'state', 'Number of INC 500 Businesses in 30 Miles', 'coded_city_state']
business_df.index = business_df['coded_city_state']
business_df = business_df[['city', 'state', 'Number of INC 500 Businesses in 30 Miles']]
business_df.sort(columns='Number of INC 500 Businesses in 30 Miles', ascending=False)
# Out:
#                               city           state  Number of INC 500 Businesses in 30 Miles
# coded_city_state
# New+York,+NY              New York        New York                                       316
# Chicago,+IL                Chicago        Illinois                                       219
# Atlanta,+GA                Atlanta         Georgia                                       181
# Los+Angeles,+CA        Los Angeles      California                                       174
# Boston,+MA                  Boston   Massachusetts                                       168
# San+Francisco,+CA    San Francisco      California                                       165
# Philadelphia,+PA      Philadelphia    Pennsylvania                                       130
# San+Jose,+CA              San Jose      California                                       116
# Seattle,+WA                Seattle      Washington                                       113
# Austin,+TX                  Austin           Texas                                        97
# San+Diego,+CA            San Diego      California                                        90
# Detroit,+MI                Detroit        Michigan                                        79
# Minneapolis,+MN        Minneapolis       Minnesota                                        78
# Salt+Lake+City,+UT  Salt Lake City            Utah                                        76
# Miami,+FL                    Miami         Florida                                        67
# Cleveland,+OH            Cleveland            Ohio                                        61
# Tampa,+FL                    Tampa         Florida                                        61
# Charlotte,+NC            Charlotte  North Carolina                                        51
# Portland,+OR              Portland          Oregon                                        49
# Raleigh,+NC                Raleigh  North Carolina                                        44
# Milwaukee,+WI            Milwaukee       Wisconsin                                        44
# Columbus,+OH              Columbus            Ohio                                        42
# Indianapolis,+IN      Indianapolis         Indiana                                        37
# Orlando,+FL                Orlando         Florida                                        32
# Oklahoma+City,+OK    Oklahoma City        Oklahoma                                        28
# Pittsburgh,+PA          Pittsburgh    Pennsylvania                                        26
# San+Antonio,+TX        San Antonio           Texas                                        23
# Las+Vegas,+NV            Las Vegas          Nevada                                        21
# Hartford,+CT              Hartford     Connecticut                                        19
# Grand+Rapids,+MI      Grand Rapids        Michigan                                        19
# Sacramento,+CA          Sacramento      California                                        19
# Omaha,+NE                    Omaha        Nebraska                                        16
# Madison,+WI                Madison       Wisconsin                                        12
