# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import re
import json
import requests
import time
import pickle
import random

# %%
def get_json_response(city_state):
    #Google Maps Sample API Link for JSON
    #"https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=API_KEY"
    Base_URL = "https://maps.googleapis.com/maps/api/geocode/json?address="
    API_Key = "&key=AIzaSyCFOt6arDLmVymOYy2TrkLrRqJRIl7zk6Q"
    google_maps_url = Base_URL + city_state + API_Key
    r = requests.get(google_maps_url)
    time.sleep(.1)
    json_file = r.json()
    coor = {}
    try:
        first_result = json_file['results'][0]   
    except IndexError:
        print "Error on Result: " + city_state
    try:   
        coor['lat'] = first_result['geometry']['location']['lat']
    except IndexError:
        print "Error on Lat: " + city_state
    try:
        coor['lon'] = first_result['geometry']['location']['lng']
    except IndexError:
        print "Error on Lon: " + city_state
    return coor

# %%
f = 'Inc_5000_raw_results.csv'

# %%
df = DataFrame.from_csv(f, index_col=None)

# %%
df = df[np.isfinite(df['rank'])]

# %%
df['city_state'] = df['city'] + ', ' + df['state']
df['coded_city_state'] = [re.sub(' ', '+', place) for place in df['city_state']]

# %%
city_state_coded = df['coded_city_state'].unique()

# %%
###TEST SCRIPT FOR API###
test = city_state_coded[1]
coordinates = get_json_response(test)
test, coordinates
# Out:
# ('North+Wales,+PA', {'lat': 40.2109404, 'lon': -75.2782317})

# %%
###ONE TIME COORDINATES GRAB. NOW IN city_state_coors.pickle###
#lat_lon_dict = {}
#for city_state in city_state_coded:
#    lat_lon_dict[city_state] = get_json_response(city_state)

# %%
#with open('city_state_coors.pickle', 'wb') as handle:
#  pickle.dump(lat_lon_dict, handle)

# %%
with open('city_state_coors.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
city_state_coors = b

# %%
test_case = df.ix[1]
city_state_coors[test_case['coded_city_state']]['lat']
# Out:
# 29.7857853

# %%
city_lat = []
city_lon = []
for ccs in df['coded_city_state']:
    next_lat = city_state_coors[ccs]['lat']
    next_lon = city_state_coors[ccs]['lon']
    city_lat.append(next_lat)
    city_lon.append(next_lon)

# %%
df['city_lat'] = city_lat
df['city_lon'] = city_lon

# %%
##Test Script, comparing results to Google API Results
##Testing for result mismatches
random_num = random.randint(1, len(city_state_coded))
test = city_state_coded[random_num]
coordinates = get_json_response(test)
print df[df['coded_city_state'] == test][['coded_city_state','city_lat', 'city_lon']]
print test, coordinates
# Out:
#        coded_city_state   city_lat   city_lon
# 1784  Schiller+Park,+IL  41.955864 -87.870897
# 3804  Schiller+Park,+IL  41.955864 -87.870897
# Schiller+Park,+IL {'lat': 41.95586369999999, 'lon': -87.8708965}

# %%
##Haversine's Formula
##Thanks to Michael Dunn
##http://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points

from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 

    # 3963.2 miles is the radius of the Earth
    miles = 3963.1676 * c
    return miles

# %%
df.tail()
# Out:
#       ﻿_input  _num                _widgetName                    _source  \
# 4995      NaN  5046  inc.com 2013 5000 crawler  inc.com 2013 5000 crawler
# 4996      NaN  5047  inc.com 2013 5000 crawler  inc.com 2013 5000 crawler
# 4997      NaN  5048  inc.com 2013 5000 crawler  inc.com 2013 5000 crawler
# 4998      NaN  5049  inc.com 2013 5000 crawler  inc.com 2013 5000 crawler
# 4999      NaN  5050  inc.com 2013 5000 crawler  inc.com 2013 5000 crawler
#
#       _resultNumber                                   _pageUrl  rank  \
# 4995           5046  http://www.inc.com/inc5000/list/2013/3700  3797
# 4996           5047  http://www.inc.com/inc5000/list/2013/3700  3798
# 4997           5048  http://www.inc.com/inc5000/list/2013/3700  3799
# 4998           5049  http://www.inc.com/inc5000/list/2013/3700  3800
# 4999           5050  http://www.inc.com/inc5000/list/2013/3700  3801
#
#       rank/_source            company_name three_year_revenue_growth  \
# 4995          3797          Restor Telecom                       76%
# 4996          3798                     AIS                       76%
# 4997          3799                    Vaco                       76%
# 4998          3800  24/7 Express Logistics                       76%
# 4999          3801                 Callcap                       76%
#
#              revenue                        industry  count_of_employees  \
# 4995   $24.1 million            ■ Telecommunications                 151
# 4996   $60.5 million                      ■ Software                 296
# 4997  $176.6 million               ■ Human Resources                 371
# 4998   $12.4 million    ■ Logistics & Transportation                  46
# 4999    $5.9 million  ■ Business Products & Services                  24
#
#                    city state             city_state       coded_city_state  \
# 4995           Leesburg    FL           Leesburg, FL           Leesburg,+FL
# 4996             Reston    VA             Reston, VA             Reston,+VA
# 4997          Brentwood    TN          Brentwood, TN          Brentwood,+TN
# 4998  North Kansas City    MO  North Kansas City, MO  North+Kansas+City,+MO
# 4999            Wichita    KS            Wichita, KS            Wichita,+KS
#
#        city_lat   city_lon
# 4995  28.810823 -81.877858
# 4996  38.958631 -77.357003
# 4997  36.033116 -86.782777
# 4998  39.142908 -94.572978
# 4999  37.688889 -97.336111

# %%
###Next section will be the function that counts
###how many cities are within r miles of a city of interest
###I am interested in getting as much data as possible, so 
###I'm considering doing every city in the list, over 1,000,000 calcs!

start_time = time.time()
test_city = 'Oak+Ridge,+TN'
base_coors = city_state_coors[test_city]
distances = []
for i in range(len(df)):
    next_city_lat = df['city_lat'].ix[i]
    next_city_lon = df['city_lon'].ix[i]
    distance_in_miles = haversine(base_coors['lon'], base_coors['lat'], next_city_lon, next_city_lat)
    distances.append(distance_in_miles)
cities_in_range = 0
r = 30 #miles
for i in distances:
    if i <= r:
        cities_in_range += 1
end_time = time.time()

print end_time - start_time, cities_in_range
# Out:
# 0.192000150681 13

# %%
# Out:
# 313.40000000000003

# %%
for i in city_state_coors.iteritems():
    print i[0]
# Out:
# Galena,+OH
# Heber+City,+UT
# Oak+Ridge,+TN
# Brooklyn+Heights,+OH
# Oakbrook+Terrace,+IL
# Liberty,+MO
# Oradell,+NJ
# Huntersville,+NC
# South+El+Monte,+CA
# Cranston,+RI
# Valdosta,+GA
# las+vegas,+NV
# Grand+Rapids,+MI
# West+Sacramento,+CA
# Oak+Park,+MI
# Payson,+AZ
# Newark,+DE
# Brown+Summit,+NC
# South+Plainfield,+NJ
# Saratoga,+CA
# Hastings,+MN
# Plainsboro,+NJ
# Minooka,+IL
# Richfield,+OH
# Morrisville,+NC
# Anderson,+IN
# Newington,+NH
# Jacksonville+Beach,+FL
# Black+Creek,+GA
# McKeesport,+PA
# Fremont,+CA
# Bloomingdale,+IL
# Roseville,+MN
# Thousand+Oaks,+CA
# Colts+Neck,+NJ
